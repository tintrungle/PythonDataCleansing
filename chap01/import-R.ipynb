# %%
import pandas as pd
import numpy as np
import pyreadr
import pprint

# %%
nls97r = pyreadr.read_r('data/nls97.rds')[None]
nls97r.dtypes
# Out:
# R0000100    int32
# R0536300    int32
# R0536401    int32
# R0536402    int32
# R1235800    int32
# R1482600    int32
# R9793800    int32
# R9793900    int32
# R9871900    int32
# R9872000    int32
# R9872200    int32
# R9872400    int32
# S8646900    int32
# S8647000    int32
# S8647100    int32
# S8647200    int32
# S8647300    int32
# S8647400    int32
# S8647500    int32
# S8647600    int32
# S8647700    int32
# S8647800    int32
# T6651700    int32
# U1836800    int32
# U1836900    int32
# U1837000    int32
# U1837100    int32
# U1837200    int32
# U1837300    int32
# U1845400    int32
# U1852400    int32
# U1852600    int32
# U1852700    int32
# U2166200    int32
# U2166300    int32
# U2166400    int32
# U2166500    int32
# U2857300    int32
# U2962800    int32
# U2962900    int32
# U2963000    int32
# Z9063900    int32
# dtype: object

# %%
nls97r.shape
# Out:
# (8984, 42)

# %%
nls97r.head(10)
# Out:
#    R0000100  R0536300  R0536401  R0536402  R1235800  R1482600  R9793800  \
# 0         1         2         9      1981         1         4       350
# 1         2         1         7      1982         1         2       460
# 2         3         2         9      1983         1         2        -4
# 3         4         2         2      1981         1         2        -4
# 4         5         1        10      1982         1         2        -4
# 5         6         2         1      1982         1         2        -4
# 6         7         1         4      1983         1         2        -4
# 7         8         2         6      1981         1         4       620
# 8         9         1        10      1982         1         4       380
# 9        10         1         3      1984         1         4       600
#
#    R9793900  R9871900  R9872000  ...  U1852700  U2166200  U2166300  U2166400  \
# 0       470       309       310  ...        -5        -5        -5        -5
# 1       440       217       280  ...        -4        -4        -4        -4
# 2        -4        -4        -4  ...         0        -4        -4        -4
# 3        -4       253       216  ...         1        -4        -4        -4
# 4        -4       243       235  ...         0        -4        -4        -4
# 5        -4       162       100  ...         0        -4        -4        -4
# 6        -4        -4        -4  ...        -5        -5        -5        -5
# 7       620       281       304  ...        -5        -5        -5        -5
# 8       460       286       290  ...        -4        -4        -4        -4
# 9       560       362       375  ...         0        -4        -4        -4
#
#    U2166500  U2857300  U2962800  U2962900  U2963000  Z9063900
# 0        -5        -5        -5        -5        -5        52
# 1        -4        -4         4         2         6         0
# 2        -4        -1         6         2         6         0
# 3        -4        -4         3         2         6         4
# 4        -4        -4         2         2         5        12
# 5        -4         3         4         2         6         6
# 6        -5        -5        -5        -5        -5         0
# 7        -5        -5        -5        -5        -5        39
# 8        -4        -4         6         2         4         0
# 9        -4        -4         6         2         6         0
#
# [10 rows x 42 columns]

# %%
with open('data/nlscodes.txt', 'r') as reader:
    setvalues = eval(reader.read())

pprint.pprint(setvalues)
# Out:
# {'R0536300': {0.0: 'No Information', 1.0: 'Male', 2.0: 'Female'},
#  'R1235800': {0.0: 'Oversample', 1.0: 'Cross-sectional'},
#  'S8646900': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647000': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647100': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647200': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647300': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647400': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647500': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647600': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647700': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647800': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'U1836800': {1.0: 'Public ',
#               2.0: 'Private not-for-profit',
#               3.0: 'Private for-profit'},
#  'U1836900': {1.0: 'Public ',
#               2.0: 'Private not-for-profit',
#               3.0: 'Private for-profit'},
#  'U1837000': {1.0: 'Public ',
#               2.0: 'Private not-for-profit',
#               3.0: 'Private for-profit'},
#  'U1837100': {1.0: 'Public ',
#               2.0: 'Private not-for-profit',
#               3.0: 'Private for-profit'},
#  'U1837200': {1.0: 'Public ',
#               2.0: 'Private not-for-profit',
#               3.0: 'Private for-profit'},
#  'U1837300': {1.0: 'Public ',
#               2.0: 'Private not-for-profit',
#               3.0: 'Private for-profit'},
#  'U1845400': {0.0: 'NONE',
#               1.0: 'A. 1ST GRADE',
#               2.0: 'B. 2ND GRADE',
#               3.0: 'C. 3RD GRADE',
#               4.0: 'D. 4TH GRADE',
#               5.0: 'E. 5TH GRADE',
#               6.0: 'F. 6TH GRADE',
#               7.0: 'G. 7TH GRADE',
#               8.0: 'H. 8TH GRADE',
#               9.0: 'I. 9TH GRADE',
#               10.0: 'J. 10TH GRADE',
#               11.0: 'K. 11TH GRADE',
#               12.0: 'L. 12TH GRADE',
#               13.0: 'M. 1ST YEAR COLLEGE',
#               14.0: 'N. 2ND YEAR COLLEGE',
#               15.0: 'O. 3RD YEAR COLLEGE',
#               16.0: 'P. 4TH YEAR COLLEGE',
#               17.0: 'Q. 5TH YEAR COLLEGE',
#               18.0: 'R. 6TH YEAR COLLEGE',
#               19.0: 'S. 7TH YEAR COLLEGE',
#               20.0: 'T. 8TH YEAR COLLEGE OR MORE',
#               95.0: '99. UNGRADED'},
#  'U1852400': {0.0: 'Never-married',
#               1.0: 'Married',
#               2.0: 'Separated',
#               3.0: 'Divorced',
#               4.0: 'Widowed'},
#  'U2166200': {1.0: '1. Associate/Junior College or two-year associate degree '
#                    '(AA)',
#               2.0: '2. Vocational or technical certificate',
#               3.0: "3. Bachelor's degree (BA, BS or unspecified)",
#               4.0: "4. Master's degree (MA, MBA, MS, MSW)",
#               5.0: '5. Doctoral Degree (PhD)',
#               6.0: '6. Professional Degree (MD, LLD, DDS, JD)',
#               7.0: '7. No degree received',
#               8.0: '8. OTHER (SPECIFY)',
#               9.0: '9. GED',
#               999.0: '999. UNCODEABLE'},
#  'U2166300': {1.0: '1. Associate/Junior College or two-year associate degree '
#                    '(AA)',
#               2.0: '2. Vocational or technical certificate',
#               3.0: "3. Bachelor's degree (BA, BS or unspecified)",
#               4.0: "4. Master's degree (MA, MBA, MS, MSW)",
#               5.0: '5. Doctoral Degree (PhD)',
#               6.0: '6. Professional Degree (MD, LLD, DDS, JD)',
#               7.0: '7. No degree received',
#               8.0: '8. OTHER (SPECIFY)',
#               9.0: '9. GED',
#               999.0: '999. UNCODEABLE'},
#  'U2166400': {1.0: '1. Associate/Junior College or two-year associate degree '
#                    '(AA)',
#               2.0: '2. Vocational or technical certificate',
#               3.0: "3. Bachelor's degree (BA, BS or unspecified)",
#               4.0: "4. Master's degree (MA, MBA, MS, MSW)",
#               5.0: '5. Doctoral Degree (PhD)',
#               6.0: '6. Professional Degree (MD, LLD, DDS, JD)',
#               7.0: '7. No degree received',
#               8.0: '8. OTHER (SPECIFY)',
#               9.0: '9. GED',
#               999.0: '999. UNCODEABLE'},
#  'U2166500': {1.0: 'Associate/Junior College or two-year associate degree (AA)',
#               2.0: '2. Vocational or technical certificate',
#               3.0: "3. Bachelor's degree (BA, BS or unspecified)",
#               4.0: "4. Master's degree (MA, MBA, MS, MSW)",
#               5.0: '5. Doctoral Degree (PhD)',
#               6.0: '6. Professional Degree (MD, LLD, DDS, JD)',
#               7.0: '7. No degree received',
#               8.0: '8. OTHER (SPECIFY)',
#               9.0: '9. GED',
#               999.0: '999. UNCODEABLE'},
#  'U2857300': {1.0: 'A. $1 - $5,000',
#               2.0: 'B. $5,001 - $10,000',
#               3.0: 'C. $10,001 - $25,000',
#               4.0: 'D. $25,001 - $50,000',
#               5.0: 'E. $50,001 - $100,000',
#               6.0: 'F. $100,001 - $250,000',
#               7.0: 'G. More than $250,000'},
#  'U2962800': {1.0: '1. None',
#               2.0: '2. Less than 1 hour a week',
#               3.0: '3. 1 to 3 hours a week',
#               4.0: '4. 4 to 6 hours a week',
#               5.0: '5. 7 to 9 hours a week',
#               6.0: '6. 10 hours or more a week'},
#  'U2962900': {1.0: '1. Less than 2 hours per week',
#               2.0: '2. 3 to 10 hours a week',
#               3.0: '3. 11 to 20 hours a week',
#               4.0: '4. 21 to 30 hours a week',
#               5.0: '5. 31 to 40 hours a week',
#               6.0: '6. More than 40 hours a week'}}

# %%
newcols = ['personid','gender','birthmonth',
    'birthyear','sampletype','category',
    'satverbal','satmath','gpaoverall',
    'gpaeng','gpamath','gpascience','govjobs',
    'govprices','govhealth','goveld','govind',
    'govunemp','govinc','govcollege',
    'govhousing','govenvironment','bacredits',
    'coltype1','coltype2','coltype3','coltype4',
    'coltype5','coltype6','highestgrade',
    'maritalstatus','childnumhome','childnumaway',
    'degreecol1','degreecol2','degreecol3',
    'degreecol4','wageincome','weeklyhrscomputer',
    'weeklyhrstv','nightlyhrssleep',
    'weeksworkedlastyear']

# %%
len(newcols)
# Out:
# 42

# %%
nls97r.shape
# Out:
# (8984, 42)

# %% [markdown]
# Mapping column name via key in metadata set setvalues

# %%
nls97r.replace(setvalues, inplace=True)
nls97r.head()
# Out:
#    R0000100 R0536300  R0536401  R0536402         R1235800  R1482600  R9793800  \
# 0         1   Female         9      1981  Cross-sectional         4       350
# 1         2     Male         7      1982  Cross-sectional         2       460
# 2         3   Female         9      1983  Cross-sectional         2        -4
# 3         4   Female         2      1981  Cross-sectional         2        -4
# 4         5     Male        10      1982  Cross-sectional         2        -4
#
#    R9793900  R9871900  R9872000  ...  U1852700  U2166200 U2166300 U2166400  \
# 0       470       309       310  ...        -5        -5       -5       -5
# 1       440       217       280  ...        -4        -4       -4       -4
# 2        -4        -4        -4  ...         0        -4       -4       -4
# 3        -4       253       216  ...         1        -4       -4       -4
# 4        -4       243       235  ...         0        -4       -4       -4
#
#   U2166500 U2857300                    U2962800                 U2962900  \
# 0       -5       -5                          -5                       -5
# 1       -4       -4      4. 4 to 6 hours a week  2. 3 to 10 hours a week
# 2       -4       -1  6. 10 hours or more a week  2. 3 to 10 hours a week
# 3       -4       -4      3. 1 to 3 hours a week  2. 3 to 10 hours a week
# 4       -4       -4  2. Less than 1 hour a week  2. 3 to 10 hours a week
#
#   U2963000 Z9063900
# 0       -5       52
# 1        6        0
# 2        6        0
# 3        6        4
# 4        5       12
#
# [5 rows x 42 columns]

# %%
nls97r.min(numeric_only=True)
# Out:
# R0000100       1
# R0536401       1
# R0536402    1980
# R1482600       1
# R9793800      -4
# R9793900      -4
# R9871900      -9
# R9872000      -9
# R9872200      -9
# R9872400      -9
# T6651700      -5
# U1852600      -5
# U1852700      -5
# U2963000      -5
# Z9063900      -4
# dtype: int32

# %%
nls97r.replace(list(range(-9,0)), np.nan, inplace=True)
for col in nls97r[[k for k in setvalues]].columns:
    nls97r[col] = nls97r[col].astype('category')

nls97r.dtypes
# Out:
# R0000100       int32
# R0536300    category
# R0536401       int32
# R0536402       int32
# R1235800    category
# R1482600       int32
# R9793800     float64
# R9793900     float64
# R9871900     float64
# R9872000     float64
# R9872200     float64
# R9872400     float64
# S8646900    category
# S8647000    category
# S8647100    category
# S8647200    category
# S8647300    category
# S8647400    category
# S8647500    category
# S8647600    category
# S8647700    category
# S8647800    category
# T6651700     float64
# U1836800    category
# U1836900    category
# U1837000    category
# U1837100    category
# U1837200    category
# U1837300    category
# U1845400    category
# U1852400    category
# U1852600     float64
# U1852700     float64
# U2166200    category
# U2166300    category
# U2166400    category
# U2166500    category
# U2857300    category
# U2962800    category
# U2962900    category
# U2963000     float64
# Z9063900     float64
# dtype: object

# %%
nls97r.columns = newcols
nls97r.dtypes
# Out:
# personid                  int32
# gender                 category
# birthmonth                int32
# birthyear                 int32
# sampletype             category
# category                  int32
# satverbal               float64
# satmath                 float64
# gpaoverall              float64
# gpaeng                  float64
# gpamath                 float64
# gpascience              float64
# govjobs                category
# govprices              category
# govhealth              category
# goveld                 category
# govind                 category
# govunemp               category
# govinc                 category
# govcollege             category
# govhousing             category
# govenvironment         category
# bacredits               float64
# coltype1               category
# coltype2               category
# coltype3               category
# coltype4               category
# coltype5               category
# coltype6               category
# highestgrade           category
# maritalstatus          category
# childnumhome            float64
# childnumaway            float64
# degreecol1             category
# degreecol2             category
# degreecol3             category
# degreecol4             category
# wageincome             category
# weeklyhrscomputer      category
# weeklyhrstv            category
# nightlyhrssleep         float64
# weeksworkedlastyear     float64
# dtype: object

# %%
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri

pandas2ri.activate()
readRDS = robjects.r['readRDS']
nls97withvalues = readRDS('data/nls97withvalues.rds')
nls97withvalues
# Out:
# <rpy2.robjects.vectors.DataFrame object at 0x7ef222672110> [19]
# R classes: ('data.frame',)
# [IntSexpVe..., IntSexpVe..., IntSexpVe..., IntSexpVe..., ..., IntSexpVe..., IntSexpVe..., IntSexpVe..., IntSexpVe...]
#   R0000100: <class 'rpy2.robjects.vectors.IntVector'>
#   <rpy2.robjects.vectors.IntVector object at 0x7ef25b52e450> [13]
# R classes: ('integer',)
# [1, 2, 3, 4, ..., 9019, 9020, 9021, 9022]
#   R0536300: <class 'rpy2.robjects.vectors.FactorVector'>
#   <rpy2.robjects.vectors.FactorVector object at 0x7ef22264b850> [13]
# R classes: ('factor',)
# [Female, Male, Female, Female, ..., Male, Male, Male, Female]
#   R0536401: <class 'rpy2.robjects.vectors.IntVector'>
#   <rpy2.robjects.vectors.IntVector object at 0x7ef24c07d050> [13]
# R classes: ('integer',)
# [9, 7, 9, 2, ..., 9, 7, 7, 1]
#   R0536402: <class 'rpy2.robjects.vectors.IntVector'>
#   <rpy2.robjects.vectors.IntVector object at 0x7ef21e6d2e90> [13]
# R classes: ('integer',)
# [1981, 1982, 1983, 1981, ..., 1984, 1980, 1980, 1982]
# ...
#   R1482600: <class 'rpy2.robjects.vectors.FactorVector'>
#   <rpy2.robjects.vectors.FactorVector object at 0x7ef21e6e4050> [13]
# R classes: ('factor',)
# [NA_integer_, 4 to ..., 10 ho..., 1 to ..., ..., Less ..., NA_integer_, 10 ho..., 10 ho...]
#   R9793800: <class 'rpy2.robjects.vectors.FactorVector'>
#   <rpy2.robjects.vectors.FactorVector object at 0x7ef22265fc90> [13]
# R classes: ('factor',)
# [NA_integer_, 3 to ..., 3 to ..., 3 to ..., ..., 3 to ..., NA_integer_, 3 to ..., Less ...]
#   R9793900: <class 'rpy2.robjects.vectors.IntVector'>
#   <rpy2.robjects.vectors.IntVector object at 0x7ef22265c8d0> [13]
# R classes: ('integer',)
# [NA_integer_, 6, 6, 6, ..., 6, NA_integer_, 7, 7]
#   R9871900: <class 'rpy2.robjects.vectors.IntVector'>
#   <rpy2.robjects.vectors.IntVector object at 0x7ef21e6d2810> [13]
# R classes: ('integer',)
# [52, 0, 0, 4, ..., 0, 15, 50, 20]
