# %%
import pandas as pd
import pyarrow

# %%
landtemps = \
pd.read_csv('data/landtempssample.csv',
names=['stationid','year','month','avgtemp',
    'latitude','longitude','elevation',
    'station','countryid','country'],
    skiprows=1,
    low_memory=False)

landtemps['measuredate'] = pd.to_datetime(landtemps[['year', 'month']].assign(day=1))
landtemps = landtemps.drop(['month', 'year'], axis=1)
landtemps.dropna(subset=['avgtemp'], inplace=True)

landtemps.dtypes
# Out:
# stationid              object
# avgtemp               float64
# latitude              float64
# longitude             float64
# elevation             float64
# station                object
# countryid              object
# country                object
# measuredate    datetime64[ns]
# dtype: object

# %%
landtemps.set_index(['measuredate', 'stationid'], inplace=True)

# %%
landtemps.head()
# Out:
#                          avgtemp  latitude  longitude  elevation  \
# measuredate stationid
# 2000-04-01  USS0010K01S     5.27   39.9000  -110.7500     2773.7
# 1940-05-01  CI000085406    18.04  -18.3500   -70.3330       58.0
# 2013-12-01  USC00036376     6.22   34.3703   -91.1242       61.0
# 1963-02-01  ASN00024002    22.93  -34.2833   140.6000       65.5
# 1991-04-01  USW00024151     5.59   42.1492  -112.2872     1362.5
#
#                                   station countryid        country
# measuredate stationid
# 2000-04-01  USS0010K01S     INDIAN_CANYON        US  United States
# 1940-05-01  CI000085406             ARICA        CI          Chile
# 2013-12-01  USC00036376     SAINT_CHARLES        US  United States
# 1963-02-01  ASN00024002  BERRI_IRRIGATION        AS      Australia
# 1991-04-01  USW00024151        MALAD_CITY        US  United States

# %%
extremevals = landtemps[(landtemps.avgtemp < landtemps.avgtemp.quantile(.001)) | (landtemps.avgtemp > landtemps.avgtemp.quantile(.999))]
extremevals.shape
# Out:
# (171, 7)

# %%
extremevals.sample(7)
# Out:
#                          avgtemp  latitude  longitude  elevation  \
# measuredate stationid
# 2017-06-01  SAM00041140    34.80   16.9010    42.5860        6.1
# 2015-05-01  SAM00041030    35.20   21.4830    39.8330      310.0
# 1959-12-01  RSM00024639   -36.52   63.2830   118.3330      119.0
# 1998-02-01  RSM00025325   -35.71   66.5500   159.4200      127.0
# 1980-07-01  ER000063043    36.38   13.0670    42.7170       14.0
# 1987-07-01  SUM00062700    35.50   16.7000    33.4333      360.0
# 1965-12-01  RSXLT854187   -35.59   70.6667   154.1500        2.0
#
#                                              station countryid       country
# measuredate stationid
# 2017-06-01  SAM00041140  KING_ABDULLAH_BIN_ABDULAZIZ        SA  Saudi Arabia
# 2015-05-01  SAM00041030                 MAKKAH_MECCA        SA  Saudi Arabia
# 1959-12-01  RSM00024639                       NJURBA        RS        Russia
# 1998-02-01  RSM00025325                     UST_OLOJ        RS        Russia
# 1980-07-01  ER000063043                        ASSAB        ER       Eritrea
# 1987-07-01  SUM00062700                       SHENDI        SU         Sudan
# 1965-12-01  RSXLT854187                      ALAZEYA        RS        Russia

# %%
extremevals.to_excel('views/tempext.xlsx')
extremevals.to_csv('views/tempext.csv')

# %%
landtemps.to_pickle('data/landtemps.pkl')
landtemps.reset_index(inplace=True)
landtemps.to_feather('data/landtemps.ftr')

# %%
landtempspkl = pd.read_pickle('data/landtemps.pkl')
landtempspkl.head(2).T
# T here is for transpose rows to columns and vice versa (columns to rows)
# Out:
# measuredate     2000-04-01  1940-05-01
# stationid      USS0010K01S CI000085406
# avgtemp               5.27       18.04
# latitude              39.9      -18.35
# longitude          -110.75     -70.333
# elevation           2773.7        58.0
# station      INDIAN_CANYON       ARICA
# countryid               US          CI
# country      United States       Chile

# %%
landtempsftr = pd.read_feather('data/landtemps.ftr')
landtempsftr.head(2).T
# Out:
#                                0                    1
# measuredate  2000-04-01 00:00:00  1940-05-01 00:00:00
# stationid            USS0010K01S          CI000085406
# avgtemp                     5.27                18.04
# latitude                    39.9               -18.35
# longitude                -110.75              -70.333
# elevation                 2773.7                 58.0
# station            INDIAN_CANYON                ARICA
# countryid                     US                   CI
# country            United States                Chile
